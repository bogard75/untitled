# %%
import numpy as np
import os
import pandas as pd

# %%
#os.getcwd()
os.chdir('/home/bogard75/다운로드')

# %%
df = pd.read_csv('Movie-Ratings.csv') # https://www.superdatascience.com/wp-content/uploads/2016/07/Movie-Ratings.csv
df
# Out:
#                                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0                 (500) Days of Summer      Comedy                         87
# 1                           10,000 B.C.  Adventure                          9
# 2                            12 Rounds      Action                         30
# 3                             127 Hours  Adventure                         93
# 4                             17 Again      Comedy                         55
# 5                                  2012     Action                         39
# 6                            27 Dresses     Comedy                         40
# 7                      30 Days of Night     Horror                         50
# 8                    30 Minutes or Less     Comedy                         43
# 9                                 50/50     Comedy                         93
# 10                           88 Minutes      Drama                          5
# ...

# %%
#df.mean()
df.describe()
#df['Rotten Tomatoes Ratings %'].mean()
#df['Audience Ratings %'].mean()
#df['Budget (million $)'].mean()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
# %matplotlib inline
df['Rotten Tomatoes Ratings %'].hist(grid=False, by=df['Genre'], sharex=True, sharey=True, layout=(4,2), figsize=(10,10), bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec6ae4c5f8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec63d25048>]], dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df.loc[:, ['Budget (million $)','Rotten Tomatoes Ratings %','Audience Ratings %']], alpha=0.2, figsize=(10, 10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec58507a20>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec583400f0>]], dtype=object)
